# %%
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# # Calling the API and Getting the Results

# %% [markdown]
# __Note:__ Unless otherwise specified, the API will return only one matching record for a search. You can specify the number of records to be returned by using the limit parameter. The maximum limit allowed is 1000 for any single API call. If no limit is set, the API will return one matching record.

# %%
# Using the url to get 1000 records available within the database
url = 'https://api.fda.gov/food/event.json?limit=1000'

r = requests.get(url)

if r.status_code == 200:
    print('API called sucessfully')
else:
    print('API not called')

# Taking a look at the raw data
#print(r.text)

# Loading the raw_data as json and Storing it as a variable
raw_data = json.loads(r.text)

# Getting only the results and store it as a variable
results = raw_data['results']
results
# Out:
# API called sucessfully
# [{'report_number': '174513',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20140311',
#   'reactions': ['DIARRHOEA', 'NAUSEA'],
#   'date_started': '20140304',
#   'consumer': {'age': '31', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ORGANIC WHOLE CASHEWS, UNSALTED',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMIN B6',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '177200',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20140617',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'BLOOD BILIRUBIN INCREASED',
#    'CHOLELITHIASIS',
#    'DECREASED APPETITE',
#    'FAECES DISCOLOURED',
#    'LIVER FUNCTION TEST ABNORMAL',
#    'NAUSEA',
#    'URINE ODOUR ABNORMAL'],
#   'date_started': '20140512',
#   'consumer': {'age': '58', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "PURITAN'S PRIDE MILK THISTLE EXTRACT 1000MG RAPID RELEASE SOFTGELS",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '178507',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20140812',
#   'reactions': ['BURNING SENSATION', 'DERMATITIS ALLERGIC', 'ERYTHEMA'],
#   'date_started': None,
#   'consumer': {'age': '26', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SUNDIAL BRANDS SHEA MOISTURE RAW SHEA BUTTER BODY WASH',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '138088',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20110321',
#   'reactions': ['CONSTIPATION',
#    'ERUCTATION',
#    'GASTROINTESTINAL DISORDER',
#    'VOMITING'],
#   'date_started': '20110319',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'COCA COLA PRODUCT SPRITE',
#     'industry_code': '29',
#     'industry_name': 'Soft Drink/Water'}]},
#  {'report_number': '135969',
#   'outcomes': ['Life Threatening', 'Hospitalization'],
#   'date_created': '20110223',
#   'reactions': ['BLOOD CREATINE PHOSPHOKINASE INCREASED',
#    'MYALGIA',
#    'RHABDOMYOLYSIS'],
#   'date_started': '20100624',
#   'consumer': {'age': '31', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'HYDROXYCUT MAX',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '158623',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20121105',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'DIZZINESS',
#    'DYSPNOEA',
#    'NAUSEA',
#    'PANIC ATTACK'],
#   'date_started': '20121012',
#   'consumer': {'age': '26', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - APPETREX CONTROL',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - WATEREX',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - MULTIVITAMIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - BALANCED MOOD SUPPORT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '153249',
#   'outcomes': ['Disability', 'Other Serious or Important Medical Event'],
#   'date_created': '20120608',
#   'reactions': ['FATIGUE',
#    'HEPATIC CIRRHOSIS',
#    'HEPATIC FUNCTION ABNORMAL',
#    'HYPOTENSION',
#    'IMPAIRED WORK ABILITY',
#    'NEPHROLITHIASIS'],
#   'date_started': None,
#   'consumer': {'age': '58', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EMERGEN-C (ASCORBIC ACID,B-COMPLEX,ELECTROLYTE,MULTIMINERAL,MULTIVIT,ZINC) POWDER FOR ORAL SOLUTION',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'POTASSIUM CHLORIDE (POTASSIUM CHLORIDE)',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '160635',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20120914',
#   'reactions': ['BLISTER',
#    'BURNING SENSATION',
#    'DRY SKIN',
#    'ERYTHEMA',
#    'RASH PAPULAR',
#    'SKIN IRRITATION'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ETERNAL LINING BLACK TATTOO INK',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'ZARKA DISTILLED WATER',
#     'industry_code': '29',
#     'industry_name': 'Soft Drink/Water'}]},
#  {'report_number': '164024',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130329',
#   'reactions': ['CHOKING'],
#   'date_started': None,
#   'consumer': {'age': '85', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "CENTRUM SILVER WOMEN'S 50+ (MULTIMINERALS, MULTIVITAMINS) TABLET",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2019-CFS-000468',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20190116',
#   'reactions': ['Dysphagia', 'Foreign body'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "PURITAN'S PRIDE COLD PRESSED CHIA OIL",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '201972',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20160920',
#   'reactions': ['HAEMATEMESIS'],
#   'date_started': None,
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'POP WEAVER POPPING CORN - EXTRA BUTTER',
#     'industry_code': '7',
#     'industry_name': 'Snack Food Item'}]},
#  {'report_number': '178737',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20140821',
#   'reactions': ['ATRIAL FIBRILLATION', 'DYSPNOEA'],
#   'date_started': None,
#   'consumer': {'age': '71', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PURITANS PRIDE GREEN COFFEE BEAN EXTRACT RAPID RELEASE CAPSULES(DIETARY SUPPLEMENT) CAPSULE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'PURITANS PRIDE NATURAL KONJAC 1000MG WHITE KIDNEY 1000MG RAP REL CAPS(DIETARY SUPPLEMENT) CAPSULE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'PURITANS PRIDE L-CARNITINE 500MG COATED CAPLETS(DIETARY SUPPLEMENT) CAPSULE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '184866',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20150413',
#   'reactions': ['ADVERSE REACTION',
#    'BURNING SENSATION',
#    'INSOMNIA',
#    'PRURITUS',
#    'SKIN IRRITATION'],
#   'date_started': '20150319',
#   'consumer': {'age': '64', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EUFORA HAIR DYE',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '186931',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20150210',
#   'reactions': ['ASTHENIA', 'DIARRHOEA', 'THROMBOSIS'],
#   'date_started': '20141109',
#   'consumer': {'age': '67', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SLOW-MAG MAGNESIUM, CALCIUM GASTRO-RESISTANT TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '187256',
#   'outcomes': ['Death'],
#   'date_created': '20150616',
#   'reactions': ['Death', 'OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'age': '50', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '192751',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20160111',
#   'reactions': ['CHOKING', 'DYSPHAGIA', 'RETCHING'],
#   'date_started': None,
#   'consumer': {'age': '57', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ONE A DAY WOMEN’S (MULTIVITAMINS+ MINERALS) FILM-COATED TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '194802',
#   'outcomes': ['Death', 'Visited a Health Care Provider'],
#   'date_created': '20160325',
#   'reactions': ['Death', 'OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2017-CFS-002788',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20171219',
#   'reactions': ['Ovarian cancer'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '200407',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20160805',
#   'reactions': ['GASTRIC DISORDER', 'OESOPHAGEAL PAIN', 'SLEEP DISORDER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ALL DAY ENERGY GREENS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2018-CFS-000907',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170628',
#   'reactions': ['Ovarian cancer'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-007562',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20180530',
#   'reactions': ['Burning sensation',
#    'Dermatitis contact',
#    'Dry skin',
#    'Erythema',
#    'Eye irritation',
#    'Hypersensitivity',
#    'Ocular hyperaemia',
#    'Pain',
#    'Pruritus',
#    'Skin exfoliation'],
#   'date_started': '20180412',
#   'consumer': {'age': '80', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-006872',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20180508',
#   'reactions': ['Alopecia', 'Hair texture abnormal', 'Trichorrhexis'],
#   'date_started': None,
#   'consumer': {'age': '35', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MONAT RENEW SHAMPOO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-007711',
#   'outcomes': ['Other Serious Outcome'],
#   'date_created': '20180602',
#   'reactions': ['Dyspepsia', 'Headache', 'Heart rate increased', 'Myalgia'],
#   'date_started': '20180528',
#   'consumer': {'age': '39', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ASHFIAT ALHARAMAIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2018-CFS-014164',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20181204',
#   'reactions': ['Hypersensitivity', 'Malaise'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SEABROOK FARMS CREAMED SPINACH',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'}]},
#  {'report_number': '110470',
#   'outcomes': ['Hospitalization', 'Visited Emergency Room'],
#   'date_created': '20090223',
#   'reactions': ['CONVULSION',
#    'DYSKINESIA',
#    'FALL',
#    'MENTAL IMPAIRMENT',
#    'PSYCHOMOTOR SKILLS IMPAIRED',
#    'VISION BLURRED'],
#   'date_started': '20090121',
#   'consumer': {'age': '27', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'IFORCE NUTRITION DYMETHAZINE 15MG',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '105110',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Other Serious Outcome'],
#   'date_created': '20080730',
#   'reactions': ['ABDOMINAL DISTENSION',
#    'BLADDER DISORDER',
#    'BLADDER PAIN',
#    'PROSTATOMEGALY',
#    'RENAL FAILURE',
#    'RENAL PAIN',
#    'STOMACH DISCOMFORT',
#    'URINARY RETENTION',
#    'URINE FLOW DECREASED'],
#   'date_started': None,
#   'consumer': {'age': '44', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "ONE A DAY MEN'S HEALTH FORMULA",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '120405',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090731',
#   'reactions': ['DIARRHOEA', 'DYSPEPSIA', 'NAUSEA'],
#   'date_started': '20090726',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "WELCH'S GRAPE JUICE",
#     'industry_code': '20',
#     'industry_name': 'Fruit/Fruit Prod'}]},
#  {'report_number': '127924',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20100625',
#   'reactions': ['CONSTIPATION', 'INTESTINAL OBSTRUCTION'],
#   'date_started': '20100613',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'VITA LEA WITH IRON',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '132542',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20100402',
#   'reactions': ['DIARRHOEA', 'VOMITING'],
#   'date_started': '20100401',
#   'consumer': {'age': '41', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FRESH EXPRESS FRESH BABY SPINACH',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'}]},
#  {'report_number': '2019-CFS-008542',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20190819',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20170201',
#   'consumer': {'age': '46', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-008560',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20230721',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '19761001',
#   'consumer': {'age': '19', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JOHNSONS POWDER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'SHOWER TO SHOWER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '204194',
#   'outcomes': ['Death'],
#   'date_created': '20161113',
#   'reactions': ['Death', 'LUNG NEOPLASM MALIGNANT', 'MESOTHELIOMA'],
#   'date_started': None,
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001843',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210930',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20140823',
#   'consumer': {'age': '38', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-007064',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20210623',
#   'reactions': ['Death', 'Ovarian cancer'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-008274',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210630',
#   'reactions': ['Ovarian cancer stage III'],
#   'date_started': '20081016',
#   'consumer': {'age': '84', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-008471',
#   'outcomes': ['Other Serious Outcome'],
#   'date_created': '20220524',
#   'reactions': ['Abdominal pain', 'Diarrhoea'],
#   'date_started': '20220508',
#   'consumer': {'age': '51', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'multi vitamin',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'calcium',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-004992',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20211117',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20130601',
#   'consumer': {'age': '30', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001641',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220202',
#   'reactions': ['Burning sensation', 'Foreign body', 'Oropharyngeal pain'],
#   'date_started': '20211201',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'NATURE MADE VITAMIN D',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-008884',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20220526',
#   'reactions': ['Aspiration', 'Cold sweat', 'Diarrhoea', 'Nausea', 'Vomiting'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'STRESS RELIEF MOOD SUPPORT SUPPLEMENT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '212209',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170523',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20140401',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-012162',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20220805',
#   'reactions': ['Abdominal pain upper',
#    'Blood bilirubin increased',
#    'Fatigue',
#    'Feeling abnormal',
#    'Hepatic enzyme increased',
#    'Malaise',
#    'Nausea',
#    'Ocular icterus',
#    'Pruritus',
#    'Vomiting',
#    'Yellow skin'],
#   'date_started': '20220519',
#   'consumer': {'age': '37', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'CONCOMITANT',
#     'name_brand': 'magnesium',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'iron',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'fish oil',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'collagen',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'b complex vitamins',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DAILY HARVEST FRENCH LENTILS + LEEK CRUMBLES',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'probiotics',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'multivitamin',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-014029',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20220104',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20120316',
#   'consumer': {'age': '63', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '202996',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20161014',
#   'reactions': ['OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-000689',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20230124',
#   'reactions': ['Impaired driving ability', 'Visual impairment'],
#   'date_started': None,
#   'consumer': {'age': '77', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PRESERVISION AREDS 2',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMIN D3',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2023-CFS-004614',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20220905',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20200608',
#   'consumer': {'age': '65', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '204486',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20161118',
#   'reactions': ['BLOOD POTASSIUM DECREASED',
#    'BODY TEMPERATURE DECREASED',
#    'CONVULSION',
#    'NAUSEA',
#    'SYNCOPE',
#    'VOMITING'],
#   'date_started': None,
#   'consumer': {'age': '73', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '41',
#     'industry_name': 'Dietary Conventional Foods/Meal Replacements'}]},
#  {'report_number': '208073',
#   'outcomes': ['Death'],
#   'date_created': '20170224',
#   'reactions': ['Death', 'OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'age': '78', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '95411',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20070813',
#   'reactions': ['ABDOMINAL DISTENSION',
#    'CHEST PAIN',
#    'DIZZINESS',
#    'HEART RATE INCREASED',
#    'HYPERHIDROSIS',
#    'MALAISE',
#    'NAUSEA',
#    'PAIN'],
#   'date_started': '20070805',
#   'consumer': {'age': '54', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SPLENDA',
#     'industry_code': '45',
#     'industry_name': 'Food Additives (Human Use)'}]},
#  {'report_number': '2022-CFS-012508',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220812',
#   'reactions': ['Foreign body'],
#   'date_started': '20220725',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CITRACAL MAXIMUM',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-013481',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220103',
#   'reactions': ['Ovarian cancer stage I'],
#   'date_started': '20150219',
#   'consumer': {'age': '44', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-000397',
#   'outcomes': ['Life Threatening'],
#   'date_created': '20200113',
#   'reactions': ['Application site swelling', 'Swelling face'],
#   'date_started': '20191201',
#   'consumer': {'age': '55', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-001909',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20200211',
#   'reactions': ['Acne cystic',
#    'Alopecia',
#    'Dandruff',
#    'Pruritus',
#    'Skin irritation'],
#   'date_started': '20190901',
#   'consumer': {'age': '29', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "DEVACURL B'LEAVE IN",
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL VOLUMIZING FOAM',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL ULTRA DEFINING GEL',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL STYLING CREAM',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL ONE CONDITION',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL NO POO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-011292',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20201103',
#   'reactions': ['Alopecia', 'Pain'],
#   'date_started': '20200825',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'STINKLEBERRY CO NATURAL DEODORANT SENSITIVE SKIN BLEND',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-009846',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20200413',
#   'reactions': ['Malaise'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BLUE DIAMOND SRIRACHA ALMONDS',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '2020-CFS-011481',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20201109',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '19800101',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-003617',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20210421',
#   'reactions': ['Diarrhoea'],
#   'date_started': None,
#   'consumer': {'age': '79', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BENEFIBER WITH WHEAT DEXTRIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-004590',
#   'outcomes': ['Death'],
#   'date_created': '20210503',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20141201',
#   'consumer': {'age': '79', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-008143',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20230802',
#   'reactions': ['Urticaria'],
#   'date_started': '20230720',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PETIT POT CHOCOLATE PUDDING',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'},
#    {'role': 'SUSPECT',
#     'name_brand': 'PETIT POT VANILLA PUDDING',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'}]},
#  {'report_number': '2022-CFS-001224',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210928',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20120408',
#   'consumer': {'age': '25', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-010611',
#   'outcomes': ['Visited a Health Care Provider'],
#   'date_created': '20211019',
#   'reactions': ['Pruritus', 'Rash'],
#   'date_started': '20211015',
#   'consumer': {'age': '41', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BLACK HENNA TATOO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001075',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210924',
#   'reactions': ['Endometrial cancer'],
#   'date_started': '20200707',
#   'consumer': {'age': '62', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-008243',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220523',
#   'reactions': ['Abdominal pain upper',
#    'Chills',
#    'Diarrhoea',
#    'Lethargy',
#    'Pyrexia',
#    'Vomiting'],
#   'date_started': '20220516',
#   'consumer': {'age': '5', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': "kids' Tylenol",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-006568',
#   'outcomes': ['Death'],
#   'date_created': '20211123',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20051110',
#   'consumer': {'age': '28', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-008418',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220524',
#   'reactions': ['Abdominal pain', 'Diarrhoea'],
#   'date_started': '20220521',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '2023-CFS-002311',
#   'outcomes': ['Other Serious Outcome'],
#   'date_created': '20230306',
#   'reactions': ['Diarrhoea', 'Vomiting'],
#   'date_started': '20230304',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FRITO LAY DORITOS NACHO CHEESE  PARTY SIZE',
#     'industry_code': '7',
#     'industry_name': 'Snack Food Item'}]},
#  {'report_number': '2023-CFS-003728',
#   'outcomes': ['Visited Emergency Room',
#    'Visited a Health Care Provider',
#    'Other Serious Outcome'],
#   'date_created': '20220728',
#   'reactions': ['Abdominal discomfort',
#    'Abdominal distension',
#    'Abdominal pain',
#    'Arthralgia',
#    'Chest pain',
#    'Dyspepsia',
#    'Dyspnoea',
#    'Hepatic enzyme increased',
#    'Pain',
#    'Tachycardia'],
#   'date_started': None,
#   'consumer': {'age': '36', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'DAILY HARVEST FRENCH LENTIL & LEEK CRUMBLES',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'}]},
#  {'report_number': '207628',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20170210',
#   'reactions': ['BACK PAIN',
#    'COUGH',
#    'FATIGUE',
#    'INCREASED UPPER AIRWAY SECRETION',
#    'MUSCULOSKELETAL PAIN',
#    'PULMONARY CONGESTION'],
#   'date_started': '20170105',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'WHEAT GRASS JUICE POWDER',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMINHERB FOR WOMEN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'PURE SYNERGY',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2023-CFS-010006',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20230912',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20170520',
#   'consumer': {'age': '81', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JOHNSONS POWDER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'SHOWER TO SHOWER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '121107',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090824',
#   'reactions': ['ALOPECIA'],
#   'date_started': '20081223',
#   'consumer': {'age': '60', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MOTIONS CLASSIC HAIR RELAXER REGULAR FORMULA FOR MEDIUM TEXTURES',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '110325',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090206',
#   'reactions': ['Abdominal pain',
#    'Diarrhoea',
#    'FEELING OF BODY TEMPERATURE CHANGE',
#    'Nausea',
#    'TREMOR',
#    'Vomiting'],
#   'date_started': '20090129',
#   'consumer': {'age': '4', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "QUAKER MOTHER'S PEANUT BUTTER BUMPERS CEREAL",
#     'industry_code': '5',
#     'industry_name': 'Cereal Prep/Breakfast Food'}]},
#  {'report_number': '128180',
#   'outcomes': ['Death', 'Hospitalization', 'Disability'],
#   'date_created': '20100701',
#   'reactions': ['BLOOD GLUCOSE DECREASED',
#    'BRAIN INJURY',
#    'CARDIOMEGALY',
#    'Death',
#    'EJECTION FRACTION DECREASED',
#    'HYPOGLYCAEMIA',
#    'LOSS OF CONSCIOUSNESS'],
#   'date_started': '20100316',
#   'consumer': {'age': '25.68', 'age_unit': 'year(s)'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'HYDROXYCUT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '207264',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170206',
#   'reactions': ['ERYTHEMA', 'PAIN'],
#   'date_started': '20170204',
#   'consumer': {'age': '46', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'DEEP CLEANING FACIAL SCRUB MASK',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '215432',
#   'outcomes': ['Death'],
#   'date_created': '20170719',
#   'reactions': ['Death', 'Ovarian cancer'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '213770',
#   'outcomes': ['Death'],
#   'date_created': '20170602',
#   'reactions': ['Death', 'Ovarian cancer'],
#   'date_started': '20120101',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '214796',
#   'outcomes': ['Hospitalization', 'Visited a Health Care Provider'],
#   'date_created': '20170705',
#   'reactions': ['ABDOMINAL PAIN',
#    'ABDOMINAL SYMPTOM',
#    'ALANINE AMINOTRANSFERASE INCREASED',
#    'ASPARTATE AMINOTRANSFERASE INCREASED',
#    'BLOOD ALKALINE PHOSPHATASE INCREASED',
#    'BLOOD BILIRUBIN INCREASED',
#    'CHOLESTASIS',
#    'CHOLESTATIC LIVER INJURY',
#    'CHROMATURIA',
#    'DECREASED APPETITE',
#    'DRUG-INDUCED LIVER INJURY',
#    'FAECES PALE',
#    'HAEMORRHAGE',
#    'HEPATIC FAILURE',
#    'HEPATITIS A ANTIBODY POSITIVE',
#    'HEPATITIS CHOLESTATIC',
#    'HEPATOMEGALY',
#    'PLATELET COUNT INCREASED',
#    'PRURITUS',
#    'TRANSAMINASES INCREASED',
#    'WEIGHT DECREASED'],
#   'date_started': '20140819',
#   'consumer': {'age': '24', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MAX MUSCLE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'ORANGE TRENT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '217146',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170628',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20130801',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '75578',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20041206',
#   'reactions': ['DIARRHOEA', 'FOOD POISONING', 'NAUSEA'],
#   'date_started': '20041201',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FIJI NATURAL SPRING WATER',
#     'industry_code': '29',
#     'industry_name': 'Soft Drink/Water'}]},
#  {'report_number': '87486',
#   'outcomes': ['Visited a Health Care Provider'],
#   'date_created': '20060707',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'BODY TEMPERATURE INCREASED',
#    'CHILLS',
#    'DIARRHOEA',
#    'MALAISE',
#    'VOMITING'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'NABISCO PREMIUM SALTINE CRACKERS',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'}]},
#  {'report_number': '95601',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20070226',
#   'reactions': ['ABDOMINAL PAIN', 'ABDOMINAL PAIN UPPER', 'DIARRHOEA'],
#   'date_started': '20070205',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PETER PAN CREAMY PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '114639',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090210',
#   'reactions': ['ABDOMINAL PAIN',
#    'DIARRHOEA',
#    'DIZZINESS',
#    'MALAISE',
#    'VOMITING'],
#   'date_started': '20080125',
#   'consumer': {'age': '30', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'LUNA NUTS OVER CHOCOLATE',
#     'industry_code': '41',
#     'industry_name': 'Dietary Conventional Foods/Meal Replacements'}]},
#  {'report_number': '127307',
#   'outcomes': ['Visited Emergency Room', 'Visited a Health Care Provider'],
#   'date_created': '20090130',
#   'reactions': ['ABDOMINAL PAIN',
#    'ABDOMINAL PAIN UPPER',
#    'ASTHENIA',
#    'DEHYDRATION',
#    'DIARRHOEA',
#    'NAUSEA',
#    'VOMITING'],
#   'date_started': '20081221',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'TWISTED PROTEIN BAR',
#     'industry_code': '33',
#     'industry_name': 'Candy W/O Choc/Special/Chew Gum'}]},
#  {'report_number': '141486',
#   'outcomes': ['Life Threatening'],
#   'date_created': '20100903',
#   'reactions': ['DYSPNOEA',
#    'FEELING OF BODY TEMPERATURE CHANGE',
#    'FLUSHING',
#    'HEADACHE',
#    'NAIL DISCOLOURATION',
#    'NASAL CONGESTION',
#    'WHEEZING'],
#   'date_started': '20100831',
#   'consumer': {'age': '38', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'WILD RAW SHRIMP',
#     'industry_code': '16',
#     'industry_name': 'Fishery/Seafood Prod'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'YELLOW FIN TUNA STEAKS',
#     'industry_code': '16',
#     'industry_name': 'Fishery/Seafood Prod'}]},
#  {'report_number': '138871',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20110503',
#   'reactions': ['EROSIVE OESOPHAGITIS', 'GASTROOESOPHAGEAL REFLUX DISEASE'],
#   'date_started': None,
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ONE A DAY ALL DAY ENERGY MULTIVITAMIN TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '143398',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20110908',
#   'reactions': ['DIARRHOEA',
#    'FLATULENCE',
#    'GASTROINTESTINAL PAIN',
#    'MALAISE',
#    'NAUSEA'],
#   'date_started': '20110810',
#   'consumer': {'age': '56', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BENEVIA STRENGTH & ENERGY',
#     'industry_code': '41',
#     'industry_name': 'Dietary Conventional Foods/Meal Replacements'}]},
#  {'report_number': '167990',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130717',
#   'reactions': ['DYSPNOEA', 'PAIN', 'PALPITATIONS'],
#   'date_started': '20130622',
#   'consumer': {'age': '49', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'NATURES BOUNTY UBIQUINOL 100MG RAPID RELEASE LIQUID SOFTGELS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'MULTIVITAMIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '151764',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20120313',
#   'reactions': ['VOMITING'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CHEERIOS MULTI GRAIN BREAKFAST CEREAL',
#     'industry_code': '5',
#     'industry_name': 'Cereal Prep/Breakfast Food'}]},
#  {'report_number': '165367',
#   'outcomes': ['Required Intervention',
#    'Visited Emergency Room',
#    'Visited a Health Care Provider'],
#   'date_created': '20110602',
#   'reactions': ['ABDOMINAL PAIN',
#    'ABDOMINAL PAIN UPPER',
#    'DIARRHOEA',
#    'HEADACHE',
#    'MALAISE',
#    'NAUSEA',
#    'VOMITING'],
#   'date_started': '20110529',
#   'consumer': {'age': '6', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'GREAT VALUE PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '169202',
#   'outcomes': ['Hospitalization', 'Visited Emergency Room'],
#   'date_created': '20130814',
#   'reactions': ['ABDOMINAL PAIN UPPER', 'NAUSEA'],
#   'date_started': '20130724',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CELLUCOR P6 EXTREME',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '171748',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20131031',
#   'reactions': ['HALLUCINATION', 'SOMNOLENCE', 'VISUAL IMPAIRMENT'],
#   'date_started': '20131021',
#   'consumer': {'age': '4', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FLINTSTONES IMMUNITY GUMMIES (MULTIVITAMINS, MULTIMINERALS, INOSITOL)',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '186351',
#   'outcomes': ['Visited a Health Care Provider'],
#   'date_created': '20150522',
#   'reactions': ['DIARRHOEA',
#    'HAEMATOCHEZIA',
#    'VIRAL TEST POSITIVE',
#    'VOMITING'],
#   'date_started': None,
#   'consumer': {'age': '6', 'age_unit': 'month(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EMFAMIL READY TO EAT LIQUID INFANT FORMULA',
#     'industry_code': '40',
#     'industry_name': 'Baby Food Products'}]},
#  {'report_number': '2017-CFS-000642',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Other Serious Outcome'],
#   'date_created': '20171009',
#   'reactions': ['Blood urine present'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SUPER BETA PROSTATE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '197119',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20160603',
#   'reactions': ['PAIN'],
#   'date_started': '20160601',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'LOOKA PATISSERIE 36 MACARONS',
# ...
#   'reactions': ['Disability'],
#   'date_started': '20201225',
#   'consumer': {'age': '67', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'KETOSLIMMD KETOGENIC BLEND 80MG',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-005876',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20210527',
#   'reactions': ['Death', 'Injury', 'Ovarian cancer stage IV'],
#   'date_started': '20150101',
#   'consumer': {'age': '61', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-014308',
#   'outcomes': ['Visited a Health Care Provider', 'Other Serious Outcome'],
#   'date_created': '20181206',
#   'reactions': ['Fungal infection'],
#   'date_started': '20181201',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PATRIOT POWER GREENS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-010926',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20210816',
#   'reactions': ['Appendix cancer', 'Death', 'Injury', 'Ovarian cancer'],
#   'date_started': '20130201',
#   'consumer': {'age': '56', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-001880',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20200211',
#   'reactions': ['Alopecia',
#    'Dandruff',
#    'Hair texture abnormal',
#    'Trichorrhexis'],
#   'date_started': '20170708',
#   'consumer': {'age': '49', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'DEVACURL NO-POO SHAMPOO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'Probiotics',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'Omega 3',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'Mutivitamins',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL ONE CONDITION',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001835',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20210930',
#   'reactions': ['Ovarian cancer stage III'],
#   'date_started': '20210409',
#   'consumer': {'age': '63', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-004089',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20211115',
#   'reactions': ['Ovarian cancer stage II'],
#   'date_started': '20090225',
#   'consumer': {'age': '75', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-002590',
#   'outcomes': ['Death'],
#   'date_created': '20210312',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '19900101',
#   'consumer': {'age': '60', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-010963',
#   'outcomes': ['Hospitalization', 'Visited a Health Care Provider'],
#   'date_created': '20201028',
#   'reactions': ['Anxiety',
#    'Hallucination',
#    'Increased upper airway secretion',
#    'Pyrexia',
#    'Respiratory arrest',
#    'Tachycardia',
#    'Tremor',
#    'Withdrawal syndrome'],
#   'date_started': '20191231',
#   'consumer': {'age': '38', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'GROUNDED ORGANICS ALL NATURAL MAENG DA PREMIUM TEA',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-009634',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20210919',
#   'reactions': ['Convulsion', 'Loss of consciousness', 'Malaise', 'Vomiting'],
#   'date_started': '20210916',
#   'consumer': {'age': '13', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PAQUI 2021 CAROLINA REAPER CHIP',
#     'industry_code': '7',
#     'industry_name': 'Snack Food Item'}]},
#  {'report_number': '211391',
#   'outcomes': ['Death'],
#   'date_created': '20170501',
#   'reactions': ['Death',
#    'Disability',
#    'Emotional distress',
#    'Injury',
#    'Ovarian cancer',
#    'Pain'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-002801',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220310',
#   'reactions': ['Cervix carcinoma', 'Ovarian cancer'],
#   'date_started': '19790101',
#   'consumer': {'age': '25.85', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-003274',
#   'outcomes': ['Life Threatening',
#    'Hospitalization',
#    'Required Intervention',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20230327',
#   'reactions': ['Cough',
#    'Hypersensitivity',
#    'Pruritus',
#    'Throat irritation',
#    'Urticaria'],
#   'date_started': '20230323',
#   'consumer': {'age': '5', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "TRADER JOE'S SESAME HONEY ALMOND",
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'gummy multivitamin daily',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2023-CFS-008038',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20230608',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20201009',
#   'consumer': {'age': '57', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JOHNSONS POWDER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-011238',
#   'outcomes': ['Death'],
#   'date_created': '20211208',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20150601',
#   'consumer': {'age': '51', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-007914',
#   'outcomes': ['Disability', 'Other Serious or Important Medical Event'],
#   'date_created': '20220523',
#   'reactions': ['Food poisoning', 'Malaise'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF CREAMY PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '207308',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20170207',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'ANORECTAL DISORDER',
#    'DIARRHOEA',
#    'DIVERTICULITIS'],
#   'date_started': None,
#   'consumer': {'age': '68', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CERTIFIED ORGANIC JUICE CLEANSE- OJC PLUS- BERRY GREENS (DIETARY SUPPLEMENT) POWDER',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '212345',
#   'outcomes': ['Death',
#    'Hospitalization',
#    'Other Serious or Important Medical Event'],
#   'date_created': '20170525',
#   'reactions': ['Death', 'Ovarian cancer stage IV'],
#   'date_started': '20140624',
#   'consumer': {'age': '57', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-014718',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220105',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20100831',
#   'consumer': {'age': '51', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '203361',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20161025',
#   'reactions': ['DYSPEPSIA',
#    'NERVOUS SYSTEM DISORDER',
#    'NEURALGIA',
#    'VITAMIN B6 INCREASED'],
#   'date_started': None,
#   'consumer': {'age': '65', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CALCIUM CITRATE MAGNESIUM AND ZINC WITH VITAMIN D3 TABLETS (DIETARY SUPPLEMENT) TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '70846',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20040714',
#   'reactions': ['Trichorrhexis'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '82509',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20051025',
#   'reactions': ['HEADACHE', 'VOMITING'],
#   'date_started': '20051025',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "HONEST TEA LORI'S LEMON TEA",
#     'industry_code': '31',
#     'industry_name': 'Coffee/Tea'}]},
#  {'report_number': '210813',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170419',
#   'reactions': ['Nephropathy', 'Renal disorder'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ONE A DAY VITACRAVES PLUS OMEGA3 DHA GUMMIES (MULTIVITAMINS, OMEGA-3 FATTY ACIDS)',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '204115',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20161110',
#   'reactions': ['OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '170564',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130926',
#   'reactions': ['ABORTION SPONTANEOUS'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "ONE A DAY WOMEN'S PRENATAL (MULTIVITAMINS + MINERALS) FILM-COATED TABLET",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '168106',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130614',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'ANXIETY',
#    'DIARRHOEA',
#    'HERPES ZOSTER',
#    'HIATUS HERNIA',
#    'IRRITABLE BOWEL SYNDROME',
#    'SKIN CANCER'],
#   'date_started': None,
#   'consumer': {'age': '84', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BENEFIBER W WHEAT DEXTRIN (NCH) (WHEAT DEXTRIN) POWDER',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMIN C ASCORBIC ACID',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'CALCIUM',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '194783',
#   'outcomes': ['Hospitalization', 'Visited Emergency Room'],
#   'date_created': '20160301',
#   'reactions': ['ADVERSE REACTION'],
#   'date_started': '20150101',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SKINSHIFT VITAMIN C SERUM',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '185510',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room',
#    'Visited a Health Care Provider'],
#   'date_created': '20150429',
#   'reactions': ['HYPERSENSITIVITY',
#    'LIP SWELLING',
#    'PRURITUS GENERALISED',
#    'URTICARIA'],
#   'date_started': '20150306',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MEANINGFUL BEAUTY WELLNESS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '197322',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20160613',
#   'reactions': ['ABDOMINAL DISCOMFORT',
#    'ABDOMINAL PAIN UPPER',
#    'BLOOD PRESSURE INCREASED',
#    'COUGH',
#    'FLATULENCE',
#    'IRRITABLE BOWEL SYNDROME',
#    'MIGRAINE',
#    'SNEEZING'],
#   'date_started': '20160612',
#   'consumer': {'age': '63', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'UNSPECIFIED BAKERY PROUDUCT',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'TRACE MINERALS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'GLUCOSAMINE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'CALCIUM ASCORBATE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'BORON',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'B-COMPLEX',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '177717',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20140701',
#   'reactions': ['VOMITING'],
#   'date_started': '20140626',
#   'consumer': {'age': '1.7', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'HORIZON VITAMIN D ORGANIC MILK DHA OMEGA 3',
#     'industry_code': '9',
#     'industry_name': 'Milk/Butter/Dried Milk Prod'}]}]

# %% [markdown]
# # Transforming the Raw data into a Data Frame

# %%
# Checking the 'reulsts' type
print(type(results))

# Taking a look at the len results
print(len(results))
# Out:
# <class 'list'>
# 1000

# %%
results
# Out:
# [{'report_number': '174513',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20140311',
#   'reactions': ['DIARRHOEA', 'NAUSEA'],
#   'date_started': '20140304',
#   'consumer': {'age': '31', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ORGANIC WHOLE CASHEWS, UNSALTED',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMIN B6',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '177200',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20140617',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'BLOOD BILIRUBIN INCREASED',
#    'CHOLELITHIASIS',
#    'DECREASED APPETITE',
#    'FAECES DISCOLOURED',
#    'LIVER FUNCTION TEST ABNORMAL',
#    'NAUSEA',
#    'URINE ODOUR ABNORMAL'],
#   'date_started': '20140512',
#   'consumer': {'age': '58', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "PURITAN'S PRIDE MILK THISTLE EXTRACT 1000MG RAPID RELEASE SOFTGELS",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '178507',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20140812',
#   'reactions': ['BURNING SENSATION', 'DERMATITIS ALLERGIC', 'ERYTHEMA'],
#   'date_started': None,
#   'consumer': {'age': '26', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SUNDIAL BRANDS SHEA MOISTURE RAW SHEA BUTTER BODY WASH',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '138088',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20110321',
#   'reactions': ['CONSTIPATION',
#    'ERUCTATION',
#    'GASTROINTESTINAL DISORDER',
#    'VOMITING'],
#   'date_started': '20110319',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'COCA COLA PRODUCT SPRITE',
#     'industry_code': '29',
#     'industry_name': 'Soft Drink/Water'}]},
#  {'report_number': '135969',
#   'outcomes': ['Life Threatening', 'Hospitalization'],
#   'date_created': '20110223',
#   'reactions': ['BLOOD CREATINE PHOSPHOKINASE INCREASED',
#    'MYALGIA',
#    'RHABDOMYOLYSIS'],
#   'date_started': '20100624',
#   'consumer': {'age': '31', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'HYDROXYCUT MAX',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '158623',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20121105',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'DIZZINESS',
#    'DYSPNOEA',
#    'NAUSEA',
#    'PANIC ATTACK'],
#   'date_started': '20121012',
#   'consumer': {'age': '26', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - APPETREX CONTROL',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - WATEREX',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - MULTIVITAMIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'GNC TOTAL LEAN LIVE LEAN & FIT PAK - BALANCED MOOD SUPPORT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '153249',
#   'outcomes': ['Disability', 'Other Serious or Important Medical Event'],
#   'date_created': '20120608',
#   'reactions': ['FATIGUE',
#    'HEPATIC CIRRHOSIS',
#    'HEPATIC FUNCTION ABNORMAL',
#    'HYPOTENSION',
#    'IMPAIRED WORK ABILITY',
#    'NEPHROLITHIASIS'],
#   'date_started': None,
#   'consumer': {'age': '58', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EMERGEN-C (ASCORBIC ACID,B-COMPLEX,ELECTROLYTE,MULTIMINERAL,MULTIVIT,ZINC) POWDER FOR ORAL SOLUTION',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'POTASSIUM CHLORIDE (POTASSIUM CHLORIDE)',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '160635',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20120914',
#   'reactions': ['BLISTER',
#    'BURNING SENSATION',
#    'DRY SKIN',
#    'ERYTHEMA',
#    'RASH PAPULAR',
#    'SKIN IRRITATION'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ETERNAL LINING BLACK TATTOO INK',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'ZARKA DISTILLED WATER',
#     'industry_code': '29',
#     'industry_name': 'Soft Drink/Water'}]},
#  {'report_number': '164024',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130329',
#   'reactions': ['CHOKING'],
#   'date_started': None,
#   'consumer': {'age': '85', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "CENTRUM SILVER WOMEN'S 50+ (MULTIMINERALS, MULTIVITAMINS) TABLET",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2019-CFS-000468',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20190116',
#   'reactions': ['Dysphagia', 'Foreign body'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "PURITAN'S PRIDE COLD PRESSED CHIA OIL",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '201972',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20160920',
#   'reactions': ['HAEMATEMESIS'],
#   'date_started': None,
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'POP WEAVER POPPING CORN - EXTRA BUTTER',
#     'industry_code': '7',
#     'industry_name': 'Snack Food Item'}]},
#  {'report_number': '178737',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20140821',
#   'reactions': ['ATRIAL FIBRILLATION', 'DYSPNOEA'],
#   'date_started': None,
#   'consumer': {'age': '71', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PURITANS PRIDE GREEN COFFEE BEAN EXTRACT RAPID RELEASE CAPSULES(DIETARY SUPPLEMENT) CAPSULE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'PURITANS PRIDE NATURAL KONJAC 1000MG WHITE KIDNEY 1000MG RAP REL CAPS(DIETARY SUPPLEMENT) CAPSULE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'PURITANS PRIDE L-CARNITINE 500MG COATED CAPLETS(DIETARY SUPPLEMENT) CAPSULE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '184866',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20150413',
#   'reactions': ['ADVERSE REACTION',
#    'BURNING SENSATION',
#    'INSOMNIA',
#    'PRURITUS',
#    'SKIN IRRITATION'],
#   'date_started': '20150319',
#   'consumer': {'age': '64', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EUFORA HAIR DYE',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '186931',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20150210',
#   'reactions': ['ASTHENIA', 'DIARRHOEA', 'THROMBOSIS'],
#   'date_started': '20141109',
#   'consumer': {'age': '67', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SLOW-MAG MAGNESIUM, CALCIUM GASTRO-RESISTANT TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '187256',
#   'outcomes': ['Death'],
#   'date_created': '20150616',
#   'reactions': ['Death', 'OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'age': '50', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '192751',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20160111',
#   'reactions': ['CHOKING', 'DYSPHAGIA', 'RETCHING'],
#   'date_started': None,
#   'consumer': {'age': '57', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ONE A DAY WOMEN’S (MULTIVITAMINS+ MINERALS) FILM-COATED TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '194802',
#   'outcomes': ['Death', 'Visited a Health Care Provider'],
#   'date_created': '20160325',
#   'reactions': ['Death', 'OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2017-CFS-002788',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20171219',
#   'reactions': ['Ovarian cancer'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '200407',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20160805',
#   'reactions': ['GASTRIC DISORDER', 'OESOPHAGEAL PAIN', 'SLEEP DISORDER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ALL DAY ENERGY GREENS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2018-CFS-000907',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170628',
#   'reactions': ['Ovarian cancer'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-007562',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20180530',
#   'reactions': ['Burning sensation',
#    'Dermatitis contact',
#    'Dry skin',
#    'Erythema',
#    'Eye irritation',
#    'Hypersensitivity',
#    'Ocular hyperaemia',
#    'Pain',
#    'Pruritus',
#    'Skin exfoliation'],
#   'date_started': '20180412',
#   'consumer': {'age': '80', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-006872',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20180508',
#   'reactions': ['Alopecia', 'Hair texture abnormal', 'Trichorrhexis'],
#   'date_started': None,
#   'consumer': {'age': '35', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MONAT RENEW SHAMPOO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-007711',
#   'outcomes': ['Other Serious Outcome'],
#   'date_created': '20180602',
#   'reactions': ['Dyspepsia', 'Headache', 'Heart rate increased', 'Myalgia'],
#   'date_started': '20180528',
#   'consumer': {'age': '39', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ASHFIAT ALHARAMAIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2018-CFS-014164',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20181204',
#   'reactions': ['Hypersensitivity', 'Malaise'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SEABROOK FARMS CREAMED SPINACH',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'}]},
#  {'report_number': '110470',
#   'outcomes': ['Hospitalization', 'Visited Emergency Room'],
#   'date_created': '20090223',
#   'reactions': ['CONVULSION',
#    'DYSKINESIA',
#    'FALL',
#    'MENTAL IMPAIRMENT',
#    'PSYCHOMOTOR SKILLS IMPAIRED',
#    'VISION BLURRED'],
#   'date_started': '20090121',
#   'consumer': {'age': '27', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'IFORCE NUTRITION DYMETHAZINE 15MG',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '105110',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Other Serious Outcome'],
#   'date_created': '20080730',
#   'reactions': ['ABDOMINAL DISTENSION',
#    'BLADDER DISORDER',
#    'BLADDER PAIN',
#    'PROSTATOMEGALY',
#    'RENAL FAILURE',
#    'RENAL PAIN',
#    'STOMACH DISCOMFORT',
#    'URINARY RETENTION',
#    'URINE FLOW DECREASED'],
#   'date_started': None,
#   'consumer': {'age': '44', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "ONE A DAY MEN'S HEALTH FORMULA",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '120405',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090731',
#   'reactions': ['DIARRHOEA', 'DYSPEPSIA', 'NAUSEA'],
#   'date_started': '20090726',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "WELCH'S GRAPE JUICE",
#     'industry_code': '20',
#     'industry_name': 'Fruit/Fruit Prod'}]},
#  {'report_number': '127924',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20100625',
#   'reactions': ['CONSTIPATION', 'INTESTINAL OBSTRUCTION'],
#   'date_started': '20100613',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'VITA LEA WITH IRON',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '132542',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20100402',
#   'reactions': ['DIARRHOEA', 'VOMITING'],
#   'date_started': '20100401',
#   'consumer': {'age': '41', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FRESH EXPRESS FRESH BABY SPINACH',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'}]},
#  {'report_number': '2019-CFS-008542',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20190819',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20170201',
#   'consumer': {'age': '46', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-008560',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20230721',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '19761001',
#   'consumer': {'age': '19', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JOHNSONS POWDER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'SHOWER TO SHOWER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '204194',
#   'outcomes': ['Death'],
#   'date_created': '20161113',
#   'reactions': ['Death', 'LUNG NEOPLASM MALIGNANT', 'MESOTHELIOMA'],
#   'date_started': None,
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001843',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210930',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20140823',
#   'consumer': {'age': '38', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-007064',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20210623',
#   'reactions': ['Death', 'Ovarian cancer'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-008274',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210630',
#   'reactions': ['Ovarian cancer stage III'],
#   'date_started': '20081016',
#   'consumer': {'age': '84', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-008471',
#   'outcomes': ['Other Serious Outcome'],
#   'date_created': '20220524',
#   'reactions': ['Abdominal pain', 'Diarrhoea'],
#   'date_started': '20220508',
#   'consumer': {'age': '51', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'multi vitamin',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'calcium',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-004992',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20211117',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20130601',
#   'consumer': {'age': '30', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001641',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220202',
#   'reactions': ['Burning sensation', 'Foreign body', 'Oropharyngeal pain'],
#   'date_started': '20211201',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'NATURE MADE VITAMIN D',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-008884',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20220526',
#   'reactions': ['Aspiration', 'Cold sweat', 'Diarrhoea', 'Nausea', 'Vomiting'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'STRESS RELIEF MOOD SUPPORT SUPPLEMENT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '212209',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170523',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20140401',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-012162',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20220805',
#   'reactions': ['Abdominal pain upper',
#    'Blood bilirubin increased',
#    'Fatigue',
#    'Feeling abnormal',
#    'Hepatic enzyme increased',
#    'Malaise',
#    'Nausea',
#    'Ocular icterus',
#    'Pruritus',
#    'Vomiting',
#    'Yellow skin'],
#   'date_started': '20220519',
#   'consumer': {'age': '37', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'CONCOMITANT',
#     'name_brand': 'magnesium',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'iron',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'fish oil',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'collagen',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'b complex vitamins',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DAILY HARVEST FRENCH LENTILS + LEEK CRUMBLES',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'probiotics',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'multivitamin',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-014029',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20220104',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20120316',
#   'consumer': {'age': '63', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '202996',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20161014',
#   'reactions': ['OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-000689',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20230124',
#   'reactions': ['Impaired driving ability', 'Visual impairment'],
#   'date_started': None,
#   'consumer': {'age': '77', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PRESERVISION AREDS 2',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMIN D3',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2023-CFS-004614',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20220905',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20200608',
#   'consumer': {'age': '65', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '204486',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20161118',
#   'reactions': ['BLOOD POTASSIUM DECREASED',
#    'BODY TEMPERATURE DECREASED',
#    'CONVULSION',
#    'NAUSEA',
#    'SYNCOPE',
#    'VOMITING'],
#   'date_started': None,
#   'consumer': {'age': '73', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '41',
#     'industry_name': 'Dietary Conventional Foods/Meal Replacements'}]},
#  {'report_number': '208073',
#   'outcomes': ['Death'],
#   'date_created': '20170224',
#   'reactions': ['Death', 'OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'age': '78', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '95411',
#   'outcomes': ['Hospitalization',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20070813',
#   'reactions': ['ABDOMINAL DISTENSION',
#    'CHEST PAIN',
#    'DIZZINESS',
#    'HEART RATE INCREASED',
#    'HYPERHIDROSIS',
#    'MALAISE',
#    'NAUSEA',
#    'PAIN'],
#   'date_started': '20070805',
#   'consumer': {'age': '54', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SPLENDA',
#     'industry_code': '45',
#     'industry_name': 'Food Additives (Human Use)'}]},
#  {'report_number': '2022-CFS-012508',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220812',
#   'reactions': ['Foreign body'],
#   'date_started': '20220725',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CITRACAL MAXIMUM',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-013481',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220103',
#   'reactions': ['Ovarian cancer stage I'],
#   'date_started': '20150219',
#   'consumer': {'age': '44', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-000397',
#   'outcomes': ['Life Threatening'],
#   'date_created': '20200113',
#   'reactions': ['Application site swelling', 'Swelling face'],
#   'date_started': '20191201',
#   'consumer': {'age': '55', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-001909',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20200211',
#   'reactions': ['Acne cystic',
#    'Alopecia',
#    'Dandruff',
#    'Pruritus',
#    'Skin irritation'],
#   'date_started': '20190901',
#   'consumer': {'age': '29', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "DEVACURL B'LEAVE IN",
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL VOLUMIZING FOAM',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL ULTRA DEFINING GEL',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL STYLING CREAM',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL ONE CONDITION',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL NO POO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-011292',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20201103',
#   'reactions': ['Alopecia', 'Pain'],
#   'date_started': '20200825',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'STINKLEBERRY CO NATURAL DEODORANT SENSITIVE SKIN BLEND',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-009846',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20200413',
#   'reactions': ['Malaise'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BLUE DIAMOND SRIRACHA ALMONDS',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '2020-CFS-011481',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20201109',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '19800101',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-003617',
#   'outcomes': ['Hospitalization'],
#   'date_created': '20210421',
#   'reactions': ['Diarrhoea'],
#   'date_started': None,
#   'consumer': {'age': '79', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BENEFIBER WITH WHEAT DEXTRIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-004590',
#   'outcomes': ['Death'],
#   'date_created': '20210503',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20141201',
#   'consumer': {'age': '79', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-008143',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20230802',
#   'reactions': ['Urticaria'],
#   'date_started': '20230720',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PETIT POT CHOCOLATE PUDDING',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'},
#    {'role': 'SUSPECT',
#     'name_brand': 'PETIT POT VANILLA PUDDING',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'}]},
#  {'report_number': '2022-CFS-001224',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210928',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20120408',
#   'consumer': {'age': '25', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-010611',
#   'outcomes': ['Visited a Health Care Provider'],
#   'date_created': '20211019',
#   'reactions': ['Pruritus', 'Rash'],
#   'date_started': '20211015',
#   'consumer': {'age': '41', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BLACK HENNA TATOO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001075',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20210924',
#   'reactions': ['Endometrial cancer'],
#   'date_started': '20200707',
#   'consumer': {'age': '62', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-008243',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220523',
#   'reactions': ['Abdominal pain upper',
#    'Chills',
#    'Diarrhoea',
#    'Lethargy',
#    'Pyrexia',
#    'Vomiting'],
#   'date_started': '20220516',
#   'consumer': {'age': '5', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': "kids' Tylenol",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2022-CFS-006568',
#   'outcomes': ['Death'],
#   'date_created': '20211123',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20051110',
#   'consumer': {'age': '28', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-008418',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220524',
#   'reactions': ['Abdominal pain', 'Diarrhoea'],
#   'date_started': '20220521',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '2023-CFS-002311',
#   'outcomes': ['Other Serious Outcome'],
#   'date_created': '20230306',
#   'reactions': ['Diarrhoea', 'Vomiting'],
#   'date_started': '20230304',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FRITO LAY DORITOS NACHO CHEESE  PARTY SIZE',
#     'industry_code': '7',
#     'industry_name': 'Snack Food Item'}]},
#  {'report_number': '2023-CFS-003728',
#   'outcomes': ['Visited Emergency Room',
#    'Visited a Health Care Provider',
#    'Other Serious Outcome'],
#   'date_created': '20220728',
#   'reactions': ['Abdominal discomfort',
#    'Abdominal distension',
#    'Abdominal pain',
#    'Arthralgia',
#    'Chest pain',
#    'Dyspepsia',
#    'Dyspnoea',
#    'Hepatic enzyme increased',
#    'Pain',
#    'Tachycardia'],
#   'date_started': None,
#   'consumer': {'age': '36', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'DAILY HARVEST FRENCH LENTIL & LEEK CRUMBLES',
#     'industry_code': '24',
#     'industry_name': 'Vegetables/Vegetable Products'}]},
#  {'report_number': '207628',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20170210',
#   'reactions': ['BACK PAIN',
#    'COUGH',
#    'FATIGUE',
#    'INCREASED UPPER AIRWAY SECRETION',
#    'MUSCULOSKELETAL PAIN',
#    'PULMONARY CONGESTION'],
#   'date_started': '20170105',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'WHEAT GRASS JUICE POWDER',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMINHERB FOR WOMEN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'PURE SYNERGY',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2023-CFS-010006',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20230912',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20170520',
#   'consumer': {'age': '81', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JOHNSONS POWDER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'SHOWER TO SHOWER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '121107',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090824',
#   'reactions': ['ALOPECIA'],
#   'date_started': '20081223',
#   'consumer': {'age': '60', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MOTIONS CLASSIC HAIR RELAXER REGULAR FORMULA FOR MEDIUM TEXTURES',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '110325',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090206',
#   'reactions': ['Abdominal pain',
#    'Diarrhoea',
#    'FEELING OF BODY TEMPERATURE CHANGE',
#    'Nausea',
#    'TREMOR',
#    'Vomiting'],
#   'date_started': '20090129',
#   'consumer': {'age': '4', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "QUAKER MOTHER'S PEANUT BUTTER BUMPERS CEREAL",
#     'industry_code': '5',
#     'industry_name': 'Cereal Prep/Breakfast Food'}]},
#  {'report_number': '128180',
#   'outcomes': ['Death', 'Hospitalization', 'Disability'],
#   'date_created': '20100701',
#   'reactions': ['BLOOD GLUCOSE DECREASED',
#    'BRAIN INJURY',
#    'CARDIOMEGALY',
#    'Death',
#    'EJECTION FRACTION DECREASED',
#    'HYPOGLYCAEMIA',
#    'LOSS OF CONSCIOUSNESS'],
#   'date_started': '20100316',
#   'consumer': {'age': '25.68', 'age_unit': 'year(s)'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'HYDROXYCUT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '207264',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170206',
#   'reactions': ['ERYTHEMA', 'PAIN'],
#   'date_started': '20170204',
#   'consumer': {'age': '46', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'DEEP CLEANING FACIAL SCRUB MASK',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '215432',
#   'outcomes': ['Death'],
#   'date_created': '20170719',
#   'reactions': ['Death', 'Ovarian cancer'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '213770',
#   'outcomes': ['Death'],
#   'date_created': '20170602',
#   'reactions': ['Death', 'Ovarian cancer'],
#   'date_started': '20120101',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '214796',
#   'outcomes': ['Hospitalization', 'Visited a Health Care Provider'],
#   'date_created': '20170705',
#   'reactions': ['ABDOMINAL PAIN',
#    'ABDOMINAL SYMPTOM',
#    'ALANINE AMINOTRANSFERASE INCREASED',
#    'ASPARTATE AMINOTRANSFERASE INCREASED',
#    'BLOOD ALKALINE PHOSPHATASE INCREASED',
#    'BLOOD BILIRUBIN INCREASED',
#    'CHOLESTASIS',
#    'CHOLESTATIC LIVER INJURY',
#    'CHROMATURIA',
#    'DECREASED APPETITE',
#    'DRUG-INDUCED LIVER INJURY',
#    'FAECES PALE',
#    'HAEMORRHAGE',
#    'HEPATIC FAILURE',
#    'HEPATITIS A ANTIBODY POSITIVE',
#    'HEPATITIS CHOLESTATIC',
#    'HEPATOMEGALY',
#    'PLATELET COUNT INCREASED',
#    'PRURITUS',
#    'TRANSAMINASES INCREASED',
#    'WEIGHT DECREASED'],
#   'date_started': '20140819',
#   'consumer': {'age': '24', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MAX MUSCLE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'ORANGE TRENT',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '217146',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170628',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20130801',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '75578',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20041206',
#   'reactions': ['DIARRHOEA', 'FOOD POISONING', 'NAUSEA'],
#   'date_started': '20041201',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FIJI NATURAL SPRING WATER',
#     'industry_code': '29',
#     'industry_name': 'Soft Drink/Water'}]},
#  {'report_number': '87486',
#   'outcomes': ['Visited a Health Care Provider'],
#   'date_created': '20060707',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'BODY TEMPERATURE INCREASED',
#    'CHILLS',
#    'DIARRHOEA',
#    'MALAISE',
#    'VOMITING'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'NABISCO PREMIUM SALTINE CRACKERS',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'}]},
#  {'report_number': '95601',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20070226',
#   'reactions': ['ABDOMINAL PAIN', 'ABDOMINAL PAIN UPPER', 'DIARRHOEA'],
#   'date_started': '20070205',
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PETER PAN CREAMY PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '114639',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20090210',
#   'reactions': ['ABDOMINAL PAIN',
#    'DIARRHOEA',
#    'DIZZINESS',
#    'MALAISE',
#    'VOMITING'],
#   'date_started': '20080125',
#   'consumer': {'age': '30', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'LUNA NUTS OVER CHOCOLATE',
#     'industry_code': '41',
#     'industry_name': 'Dietary Conventional Foods/Meal Replacements'}]},
#  {'report_number': '127307',
#   'outcomes': ['Visited Emergency Room', 'Visited a Health Care Provider'],
#   'date_created': '20090130',
#   'reactions': ['ABDOMINAL PAIN',
#    'ABDOMINAL PAIN UPPER',
#    'ASTHENIA',
#    'DEHYDRATION',
#    'DIARRHOEA',
#    'NAUSEA',
#    'VOMITING'],
#   'date_started': '20081221',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'TWISTED PROTEIN BAR',
#     'industry_code': '33',
#     'industry_name': 'Candy W/O Choc/Special/Chew Gum'}]},
#  {'report_number': '141486',
#   'outcomes': ['Life Threatening'],
#   'date_created': '20100903',
#   'reactions': ['DYSPNOEA',
#    'FEELING OF BODY TEMPERATURE CHANGE',
#    'FLUSHING',
#    'HEADACHE',
#    'NAIL DISCOLOURATION',
#    'NASAL CONGESTION',
#    'WHEEZING'],
#   'date_started': '20100831',
#   'consumer': {'age': '38', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'WILD RAW SHRIMP',
#     'industry_code': '16',
#     'industry_name': 'Fishery/Seafood Prod'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'YELLOW FIN TUNA STEAKS',
#     'industry_code': '16',
#     'industry_name': 'Fishery/Seafood Prod'}]},
#  {'report_number': '138871',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20110503',
#   'reactions': ['EROSIVE OESOPHAGITIS', 'GASTROOESOPHAGEAL REFLUX DISEASE'],
#   'date_started': None,
#   'consumer': {'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ONE A DAY ALL DAY ENERGY MULTIVITAMIN TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '143398',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20110908',
#   'reactions': ['DIARRHOEA',
#    'FLATULENCE',
#    'GASTROINTESTINAL PAIN',
#    'MALAISE',
#    'NAUSEA'],
#   'date_started': '20110810',
#   'consumer': {'age': '56', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BENEVIA STRENGTH & ENERGY',
#     'industry_code': '41',
#     'industry_name': 'Dietary Conventional Foods/Meal Replacements'}]},
#  {'report_number': '167990',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130717',
#   'reactions': ['DYSPNOEA', 'PAIN', 'PALPITATIONS'],
#   'date_started': '20130622',
#   'consumer': {'age': '49', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'NATURES BOUNTY UBIQUINOL 100MG RAPID RELEASE LIQUID SOFTGELS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'MULTIVITAMIN',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '151764',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20120313',
#   'reactions': ['VOMITING'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CHEERIOS MULTI GRAIN BREAKFAST CEREAL',
#     'industry_code': '5',
#     'industry_name': 'Cereal Prep/Breakfast Food'}]},
#  {'report_number': '165367',
#   'outcomes': ['Required Intervention',
#    'Visited Emergency Room',
#    'Visited a Health Care Provider'],
#   'date_created': '20110602',
#   'reactions': ['ABDOMINAL PAIN',
#    'ABDOMINAL PAIN UPPER',
#    'DIARRHOEA',
#    'HEADACHE',
#    'MALAISE',
#    'NAUSEA',
#    'VOMITING'],
#   'date_started': '20110529',
#   'consumer': {'age': '6', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'GREAT VALUE PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '169202',
#   'outcomes': ['Hospitalization', 'Visited Emergency Room'],
#   'date_created': '20130814',
#   'reactions': ['ABDOMINAL PAIN UPPER', 'NAUSEA'],
#   'date_started': '20130724',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CELLUCOR P6 EXTREME',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '171748',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20131031',
#   'reactions': ['HALLUCINATION', 'SOMNOLENCE', 'VISUAL IMPAIRMENT'],
#   'date_started': '20131021',
#   'consumer': {'age': '4', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'FLINTSTONES IMMUNITY GUMMIES (MULTIVITAMINS, MULTIMINERALS, INOSITOL)',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '186351',
#   'outcomes': ['Visited a Health Care Provider'],
#   'date_created': '20150522',
#   'reactions': ['DIARRHOEA',
#    'HAEMATOCHEZIA',
#    'VIRAL TEST POSITIVE',
#    'VOMITING'],
#   'date_started': None,
#   'consumer': {'age': '6', 'age_unit': 'month(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EMFAMIL READY TO EAT LIQUID INFANT FORMULA',
#     'industry_code': '40',
#     'industry_name': 'Baby Food Products'}]},
#  {'report_number': '2017-CFS-000642',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Other Serious Outcome'],
#   'date_created': '20171009',
#   'reactions': ['Blood urine present'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SUPER BETA PROSTATE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '197119',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20160603',
#   'reactions': ['PAIN'],
#   'date_started': '20160601',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'LOOKA PATISSERIE 36 MACARONS',
#     'industry_code': '3',
# ...
#   'reactions': ['Disability'],
#   'date_started': '20201225',
#   'consumer': {'age': '67', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'KETOSLIMMD KETOGENIC BLEND 80MG',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-005876',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20210527',
#   'reactions': ['Death', 'Injury', 'Ovarian cancer stage IV'],
#   'date_started': '20150101',
#   'consumer': {'age': '61', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2018-CFS-014308',
#   'outcomes': ['Visited a Health Care Provider', 'Other Serious Outcome'],
#   'date_created': '20181206',
#   'reactions': ['Fungal infection'],
#   'date_started': '20181201',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PATRIOT POWER GREENS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-010926',
#   'outcomes': ['Death', 'Other Serious or Important Medical Event'],
#   'date_created': '20210816',
#   'reactions': ['Appendix cancer', 'Death', 'Injury', 'Ovarian cancer'],
#   'date_started': '20130201',
#   'consumer': {'age': '56', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-001880',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20200211',
#   'reactions': ['Alopecia',
#    'Dandruff',
#    'Hair texture abnormal',
#    'Trichorrhexis'],
#   'date_started': '20170708',
#   'consumer': {'age': '49', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'DEVACURL NO-POO SHAMPOO',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'Probiotics',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'Omega 3',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'Mutivitamins',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'SUSPECT',
#     'name_brand': 'DEVACURL ONE CONDITION',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-001835',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20210930',
#   'reactions': ['Ovarian cancer stage III'],
#   'date_started': '20210409',
#   'consumer': {'age': '63', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-004089',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20211115',
#   'reactions': ['Ovarian cancer stage II'],
#   'date_started': '20090225',
#   'consumer': {'age': '75', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2021-CFS-002590',
#   'outcomes': ['Death'],
#   'date_created': '20210312',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '19900101',
#   'consumer': {'age': '60', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2020-CFS-010963',
#   'outcomes': ['Hospitalization', 'Visited a Health Care Provider'],
#   'date_created': '20201028',
#   'reactions': ['Anxiety',
#    'Hallucination',
#    'Increased upper airway secretion',
#    'Pyrexia',
#    'Respiratory arrest',
#    'Tachycardia',
#    'Tremor',
#    'Withdrawal syndrome'],
#   'date_started': '20191231',
#   'consumer': {'age': '38', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'GROUNDED ORGANICS ALL NATURAL MAENG DA PREMIUM TEA',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2021-CFS-009634',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20210919',
#   'reactions': ['Convulsion', 'Loss of consciousness', 'Malaise', 'Vomiting'],
#   'date_started': '20210916',
#   'consumer': {'age': '13', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'PAQUI 2021 CAROLINA REAPER CHIP',
#     'industry_code': '7',
#     'industry_name': 'Snack Food Item'}]},
#  {'report_number': '211391',
#   'outcomes': ['Death'],
#   'date_created': '20170501',
#   'reactions': ['Death',
#    'Disability',
#    'Emotional distress',
#    'Injury',
#    'Ovarian cancer',
#    'Pain'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-002801',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220310',
#   'reactions': ['Cervix carcinoma', 'Ovarian cancer'],
#   'date_started': '19790101',
#   'consumer': {'age': '25.85', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2023-CFS-003274',
#   'outcomes': ['Life Threatening',
#    'Hospitalization',
#    'Required Intervention',
#    'Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20230327',
#   'reactions': ['Cough',
#    'Hypersensitivity',
#    'Pruritus',
#    'Throat irritation',
#    'Urticaria'],
#   'date_started': '20230323',
#   'consumer': {'age': '5', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "TRADER JOE'S SESAME HONEY ALMOND",
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'gummy multivitamin daily',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '2023-CFS-008038',
#   'outcomes': ['Hospitalization', 'Other Serious or Important Medical Event'],
#   'date_created': '20230608',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20201009',
#   'consumer': {'age': '57', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JOHNSONS POWDER NO UPC',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-011238',
#   'outcomes': ['Death'],
#   'date_created': '20211208',
#   'reactions': ['Death', 'Injury'],
#   'date_started': '20150601',
#   'consumer': {'age': '51', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-007914',
#   'outcomes': ['Disability', 'Other Serious or Important Medical Event'],
#   'date_created': '20220523',
#   'reactions': ['Food poisoning', 'Malaise'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'JIF CREAMY PEANUT BUTTER',
#     'industry_code': '23',
#     'industry_name': 'Nuts/Edible Seed'}]},
#  {'report_number': '207308',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room'],
#   'date_created': '20170207',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'ANORECTAL DISORDER',
#    'DIARRHOEA',
#    'DIVERTICULITIS'],
#   'date_started': None,
#   'consumer': {'age': '68', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CERTIFIED ORGANIC JUICE CLEANSE- OJC PLUS- BERRY GREENS (DIETARY SUPPLEMENT) POWDER',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '212345',
#   'outcomes': ['Death',
#    'Hospitalization',
#    'Other Serious or Important Medical Event'],
#   'date_created': '20170525',
#   'reactions': ['Death', 'Ovarian cancer stage IV'],
#   'date_started': '20140624',
#   'consumer': {'age': '57', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '2022-CFS-014718',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20220105',
#   'reactions': ['Ovarian cancer'],
#   'date_started': '20100831',
#   'consumer': {'age': '51', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '203361',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20161025',
#   'reactions': ['DYSPEPSIA',
#    'NERVOUS SYSTEM DISORDER',
#    'NEURALGIA',
#    'VITAMIN B6 INCREASED'],
#   'date_started': None,
#   'consumer': {'age': '65', 'age_unit': 'year(s)', 'gender': 'Male'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'CALCIUM CITRATE MAGNESIUM AND ZINC WITH VITAMIN D3 TABLETS (DIETARY SUPPLEMENT) TABLET',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '70846',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20040714',
#   'reactions': ['Trichorrhexis'],
#   'date_started': None,
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '82509',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20051025',
#   'reactions': ['HEADACHE', 'VOMITING'],
#   'date_started': '20051025',
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "HONEST TEA LORI'S LEMON TEA",
#     'industry_code': '31',
#     'industry_name': 'Coffee/Tea'}]},
#  {'report_number': '210813',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20170419',
#   'reactions': ['Nephropathy', 'Renal disorder'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'ONE A DAY VITACRAVES PLUS OMEGA3 DHA GUMMIES (MULTIVITAMINS, OMEGA-3 FATTY ACIDS)',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '204115',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited a Health Care Provider'],
#   'date_created': '20161110',
#   'reactions': ['OVARIAN CANCER'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'},
#    {'role': 'SUSPECT',
#     'name_brand': 'EXEMPTION 4',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '170564',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130926',
#   'reactions': ['ABORTION SPONTANEOUS'],
#   'date_started': None,
#   'consumer': {'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': "ONE A DAY WOMEN'S PRENATAL (MULTIVITAMINS + MINERALS) FILM-COATED TABLET",
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '168106',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20130614',
#   'reactions': ['ABDOMINAL PAIN UPPER',
#    'ANXIETY',
#    'DIARRHOEA',
#    'HERPES ZOSTER',
#    'HIATUS HERNIA',
#    'IRRITABLE BOWEL SYNDROME',
#    'SKIN CANCER'],
#   'date_started': None,
#   'consumer': {'age': '84', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'BENEFIBER W WHEAT DEXTRIN (NCH) (WHEAT DEXTRIN) POWDER',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'VITAMIN C ASCORBIC ACID',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'CALCIUM',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '194783',
#   'outcomes': ['Hospitalization', 'Visited Emergency Room'],
#   'date_created': '20160301',
#   'reactions': ['ADVERSE REACTION'],
#   'date_started': '20150101',
#   'consumer': {},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'SKINSHIFT VITAMIN C SERUM',
#     'industry_code': '53',
#     'industry_name': 'Cosmetics'}]},
#  {'report_number': '185510',
#   'outcomes': ['Other Serious or Important Medical Event',
#    'Visited Emergency Room',
#    'Visited a Health Care Provider'],
#   'date_created': '20150429',
#   'reactions': ['HYPERSENSITIVITY',
#    'LIP SWELLING',
#    'PRURITUS GENERALISED',
#    'URTICARIA'],
#   'date_started': '20150306',
#   'consumer': {'age': '43', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'MEANINGFUL BEAUTY WELLNESS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '197322',
#   'outcomes': ['Other Serious or Important Medical Event'],
#   'date_created': '20160613',
#   'reactions': ['ABDOMINAL DISCOMFORT',
#    'ABDOMINAL PAIN UPPER',
#    'BLOOD PRESSURE INCREASED',
#    'COUGH',
#    'FLATULENCE',
#    'IRRITABLE BOWEL SYNDROME',
#    'MIGRAINE',
#    'SNEEZING'],
#   'date_started': '20160612',
#   'consumer': {'age': '63', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'UNSPECIFIED BAKERY PROUDUCT',
#     'industry_code': '3',
#     'industry_name': 'Bakery Prod/Dough/Mix/Icing'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'TRACE MINERALS',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'GLUCOSAMINE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'CALCIUM ASCORBATE',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'BORON',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'},
#    {'role': 'CONCOMITANT',
#     'name_brand': 'B-COMPLEX',
#     'industry_code': '54',
#     'industry_name': 'Vit/Min/Prot/Unconv Diet(Human/Animal)'}]},
#  {'report_number': '177717',
#   'outcomes': ['Other Outcome'],
#   'date_created': '20140701',
#   'reactions': ['VOMITING'],
#   'date_started': '20140626',
#   'consumer': {'age': '1.7', 'age_unit': 'year(s)', 'gender': 'Female'},
#   'products': [{'role': 'SUSPECT',
#     'name_brand': 'HORIZON VITAMIN D ORGANIC MILK DHA OMEGA 3',
#     'industry_code': '9',
#     'industry_name': 'Milk/Butter/Dried Milk Prod'}]}]

# %%
# Initialiaze an empty dictionary to store the data
df = []

# For loop to iterate each list element
for i in range(0,len(results)):

    # Try to store the data as variables
    try:
        report_number = results[i]['report_number']
        outcomes = results[i]['outcomes']
        date_created = results[i]['date_created']
        reactions = results[i]['reactions']
        consumer_age = results[i]['consumer']['age']
        consumer_age_unit = results[i]['consumer']['age_unit']
        consumer_gender = results[i]['consumer']['gender']
         
        """
Since there are reports linked to multiple products, we will create a list containing the product data
and add it to the final dataframe. Subsequently, a new column 'products' will be created which will contain a list of all associated products.
We will then use the 'explode' function in Python to split each element of the list into separate rows, representing individual products, and then
extract the product details for analysis.
        """


        # Initiliaze an empty list to store the products data
        products = []

        # getting products data
        for product in results[i]['products']:
            product_role = product['role']
            product_name_brand = product['name_brand']
            product_industry_code = product['industry_code']
            product_industry_name = product['industry_name']

        # append products data into the empty list
            products.append({
                'product_role': product_role,
                'product_name_brand': product_name_brand,
                'product_industry_code': product_industry_code,
                'product_industry_name': product_industry_name
            })

    # If there is no data store it as missing data (nan)
    except:
        report_number = np.nan
        outcomes = np.nan
        date_created = np.nan
        reactions = np.nan
        consumer_age = np.nan
        consumer_age_unit = np.nan
        consumer_gender = np.nan

    # Append the variables in the dictionary
    df.append({
        'report_number':report_number,
        'outcomes':outcomes,
        'date_created':date_created,
        'reactions': reactions,
        'consumer_age':consumer_age,
        'consumer_age_unit':consumer_age_unit,
        'consumer_gender':consumer_gender,
        'products': products})

# Transforming the dictionary into a pandas dataframe
df = pd.DataFrame(df)


# Using 'explode' function to create a row for each element in the 'products' column list
df = df.explode('products')

# Getting the products 'role', 'brand_name' etc... 
df['product_role'] = df['products'].apply(lambda x: x['product_role'])
df['product_name_brand'] = df['products'].apply(lambda x: x['product_name_brand'])
df['product_industry_code'] = df['products'].apply(lambda x: x['product_industry_code'])
df['product_industry_name'] = df['products'].apply(lambda x: x['product_industry_name'])

# Droping the 'products' column as we don't need it anymore
df = df.drop(columns = 'products')

# The 'outcomes' and 'reactions' are also columns  where those values are inside a list
# That said let's use the 'explode function again to create a row for each element inside the list
df = df.explode('outcomes')
df = df.explode('reactions')

df
# Out:
#     report_number                                  outcomes date_created  \
# 0          174513                             Other Outcome     20140311
# 0          174513                             Other Outcome     20140311
# 0          174513                             Other Outcome     20140311
# 0          174513                             Other Outcome     20140311
# 1          177200  Other Serious or Important Medical Event     20140617
# ..            ...                                       ...          ...
# 998        197322  Other Serious or Important Medical Event     20160613
# 998        197322  Other Serious or Important Medical Event     20160613
# 998        197322  Other Serious or Important Medical Event     20160613
# 998        197322  Other Serious or Important Medical Event     20160613
# 999        177717                             Other Outcome     20140701
#
#                     reactions consumer_age consumer_age_unit consumer_gender  \
# 0                   DIARRHOEA           31           year(s)          Female
# 0                      NAUSEA           31           year(s)          Female
# 0                   DIARRHOEA           31           year(s)          Female
# 0                      NAUSEA           31           year(s)          Female
# 1        ABDOMINAL PAIN UPPER           58           year(s)          Female
# ..                        ...          ...               ...             ...
# 998                FLATULENCE           63           year(s)          Female
# 998  IRRITABLE BOWEL SYNDROME           63           year(s)          Female
# 998                  MIGRAINE           63           year(s)          Female
# 998                  SNEEZING           63           year(s)          Female
# 999                  VOMITING          1.7           year(s)          Female
#
#     product_role                                 product_name_brand  \
# 0        SUSPECT                    ORGANIC WHOLE CASHEWS, UNSALTED
# 0        SUSPECT                    ORGANIC WHOLE CASHEWS, UNSALTED
# 0    CONCOMITANT                                         VITAMIN B6
# 0    CONCOMITANT                                         VITAMIN B6
# 1        SUSPECT  PURITAN'S PRIDE MILK THISTLE EXTRACT 1000MG RA...
# ..           ...                                                ...
# 998  CONCOMITANT                                          B-COMPLEX
# 998  CONCOMITANT                                          B-COMPLEX
# 998  CONCOMITANT                                          B-COMPLEX
# 998  CONCOMITANT                                          B-COMPLEX
# 999      SUSPECT         HORIZON VITAMIN D ORGANIC MILK DHA OMEGA 3
#
#     product_industry_code                   product_industry_name
# 0                      23                        Nuts/Edible Seed
# 0                      23                        Nuts/Edible Seed
# 0                      54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 0                      54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 1                      54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# ..                    ...                                     ...
# 998                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 998                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 998                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 998                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 999                     9             Milk/Butter/Dried Milk Prod
#
# [6030 rows x 11 columns]
